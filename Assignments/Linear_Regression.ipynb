# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate synthetic dataset
def generate_data(n=100, noise=5):
    X = np.linspace(0, 10, n)
    y = 2.5 * X + 7 + np.random.randn(n) * noise  # y = 2.5x + 7 + noise
    return X.reshape(-1, 1), y.reshape(-1, 1)

# %%
# Mean Squared Error
def mse(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# %%
# Linear Regression using Gradient Descent
def linear_regression(X, y, lr=0.01, epochs=1000):
    m, n = X.shape
    X_b = np.c_[np.ones((m, 1)), X]  # Add bias term
    theta = np.random.randn(n + 1, 1)  # Initialize weights

    for _ in range(epochs):
        gradients = (2/m) * X_b.T @ (X_b @ theta - y)  # Compute gradients
        theta -= lr * gradients  # Update parameters

    return theta

# %%
# Generate data
X, y = generate_data()

# %%
# Train model
theta = linear_regression(X, y)

# %%
# Predictions
X_b = np.c_[np.ones((X.shape[0], 1)), X]
y_pred = X_b @ theta

# %%
# Visualize results
plt.scatter(X, y, color='blue', alpha=0.5, label='Data')
plt.plot(X, y_pred, color='red', label='Regression Line')
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.title("Linear Regression from Scratch")
plt.show()

# %%
# Print final parameters
print(f"Final model: y = {theta[1,0]:.2f}x + {theta[0,0]:.2f}")
# Out:
# Final model: y = 2.38x + 7.23
